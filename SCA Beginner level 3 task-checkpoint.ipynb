# %%
import numpy as np

# %%
Exercise_1 = np.arange(100,200,10)
Exercise_1 = Exercise_1.reshape(5,2)
print(Exercise_1)
# Out:
# [[100 110]
#  [120 130]
#  [140 150]
#  [160 170]
#  [180 190]]

# %%
sampleArray = np.array([[11,22,33], [44,55,66], [77,88,99]]) 
print(sampleArray[0:,2])
# Out:
# [33 66 99]

# %%
arrayOne = np.array([[5,6,9], [21,18,27]])
arrayTwo = np.array([[15,33,24], [4,7,1]])
ResultArray = arrayOne+arrayTwo
print(ResultArray)
# Out:
# [[20 39 33]
#  [25 25 28]]

# %%
Exercise_3 = np.square(ResultArray)
print(Exercise_3)
# Out:
# [[ 400 1521 1089]
#  [ 625  625  784]]

# %%
import pandas as pd

# %%
df = pd.read_csv("Automobile_data.csv")
pd.set_option('display.max_rows', 10)



df
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan        97.3   171.7         ohc
# 58     86   volkswagen        sedan        97.3   171.7         ohc
# 59     87        volvo        sedan       104.3   188.8         ohc
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four         111               21  13495.0
# ...

# %%
df.replace(["?", "n.a"], value = "NaN", inplace = True)

# %%
df['price'].idxmax()
# Out:
# 35

# %%
first = df.loc[[35], ['company', 'price']]
first
# Out:
#           company    price
# 35  mercedes-benz  45400.0

# %%
pd.set_option('display.max_rows', None)
df.groupby("company").describe().loc["toyota",  :]
# Out:
# index            count        7.000000
#                  mean        70.000000
#                  std          4.320494
#                  min         66.000000
#                  25%         67.500000
#                  50%         69.000000
#                  75%         70.500000
#                  max         79.000000
# wheel-base       count        7.000000
#                  mean        96.957143
#                  std          3.326087
#                  min         95.700000
#                  25%         95.700000
#                  50%         95.700000
#                  75%         95.700000
#                  max        104.500000
# length           count        7.000000
#                  mean       167.571429
#                  std         10.479299
#                  min        158.700000
#                  25%        158.700000
#                  50%        169.700000
#                  75%        169.700000
#                  max        187.800000
# ...

# %%
df['company'].groupby(df["company"]).count()
# Out:
# company
# alfa-romero      3
# audi             4
# bmw              6
# chevrolet        3
# dodge            2
# honda            3
# isuzu            3
# jaguar           3
# mazda            5
# mercedes-benz    4
# mitsubishi       4
# nissan           5
# porsche          3
# toyota           7
# volkswagen       4
# volvo            2
# Name: company, dtype: int64

# %%
df['price'].groupby(df["company"]).max()
# Out:
# company
# alfa-romero      16500.0
# audi             18920.0
# bmw              41315.0
# chevrolet         6575.0
# dodge             6377.0
# honda            12945.0
# isuzu             6785.0
# jaguar           36000.0
# mazda            18344.0
# mercedes-benz    45400.0
# mitsubishi        8189.0
# nissan           13499.0
# porsche          37028.0
# toyota           15750.0
# volkswagen        9995.0
# volvo            13415.0
# Name: price, dtype: float64

# %%
df['average-mileage'].groupby(df["company"]).mean()
# Out:
# company
# alfa-romero      20.333333
# audi             20.000000
# bmw              19.000000
# chevrolet        41.000000
# dodge            31.000000
# honda            26.333333
# isuzu            33.333333
# jaguar           14.333333
# mazda            28.000000
# mercedes-benz    18.000000
# mitsubishi       29.500000
# nissan           31.400000
# porsche          17.000000
# toyota           28.714286
# volkswagen       31.750000
# volvo            23.000000
# Name: average-mileage, dtype: float64

# %%
df.sort_values(by=['price'])
# Out:
#     index        company   body-style  wheel-base  length engine-type  \
# 13     16      chevrolet    hatchback        88.4   141.1           l
# 27     36          mazda    hatchback        93.1   159.1         ohc
# 48     66         toyota    hatchback        95.7   158.7         ohc
# 36     49     mitsubishi    hatchback        93.7   157.3         ohc
# 28     37          mazda    hatchback        93.1   159.1         ohc
# 37     50     mitsubishi    hatchback        93.7   157.3         ohc
# 17     20          dodge    hatchback        93.7   157.3         ohc
# 14     17      chevrolet    hatchback        94.5   155.9         ohc
# 49     67         toyota    hatchback        95.7   158.7         ohc
# 16     19          dodge    hatchback        93.7   157.3         ohc
# 50     68         toyota    hatchback        95.7   158.7         ohc
# 15     18      chevrolet        sedan        94.5   158.8         ohc
# ...

# %%
GermanCars = {'Company': ['Ford', 'Mercedes', 'BMV', 'Audi'], 'Price': [23845, 171995, 135925 , 71400]}
japaneseCars = {'Company': ['Toyota', 'Honda', 'Nissan', 'Mitsubishi '], 'Price': [29995, 23600, 61500 , 58900]}
GermCar = pd.DataFrame(GermanCars)
JapaCar = pd.DataFrame(japaneseCars)
print(GermCar)
print(JapaCar)
# Out:
#     Company   Price
# 0      Ford   23845
# 1  Mercedes  171995
# 2       BMV  135925
# 3      Audi   71400
#        Company  Price
# 0       Toyota  29995
# 1        Honda  23600
# 2       Nissan  61500
# 3  Mitsubishi   58900

# %%
world_Cars = pd.concat([GermCar, JapaCar], keys = ["GermanCars", "japaneseCars"])
world_Cars
# Out:
#                     Company   Price
# GermanCars   0         Ford   23845
#              1     Mercedes  171995
#              2          BMV  135925
#              3         Audi   71400
# japaneseCars 0       Toyota   29995
#              1        Honda   23600
#              2       Nissan   61500
#              3  Mitsubishi    58900

# %%
Car_Price = {'Company': ['Toyota', 'Honda', 'BMV', 'Audi'], 'Price': [23845, 17995, 135925 , 71400]}
car_Horsepower = {'Company': ['Toyota', 'Honda', 'BMV', 'Audi'], 'horsepower': [141, 80, 182 , 160]}
CarPrice = pd.DataFrame(Car_Price)
CarHorsepower = pd.DataFrame(car_Horsepower)
pd.merge(CarPrice, CarHorsepower, on = "Company" )
# Out:
#   Company   Price  horsepower
# 0  Toyota   23845         141
# 1   Honda   17995          80
# 2     BMV  135925         182
# 3    Audi   71400         160

# %%
import matplotlib.pyplot as plt

# %%
#MATPLOTLIB

# %%
CompanySales = pd.read_csv("company_sales_data.xls")
CompanySales
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
# ...

# %%
plt.figure(figsize = (10,8))
plt.plot(CompanySales['month_number'],
           CompanySales['total_profit'])
plt.xlabel('Month of the Year')
plt.ylabel('Total Profit')
plt.title('Company Profit per Month')
plt.xticks(ticks = range(1,13))
plt.yticks(ticks = range(100000,600000,100000))
plt.show()

# %%
labels = ['FaceCream', 'FaceWash', 'Toothpaste', 'BathingSoap', 'Shampoo', 'Moisturizer' ]
plt.figure(figsize = (10,8))
plt.plot(CompanySales['month_number'], CompanySales['facecream'], marker = "o")
plt.plot(CompanySales['month_number'], CompanySales['facewash'], marker = "o")
plt.plot(CompanySales['month_number'], CompanySales['toothpaste'], marker = "o")
plt.plot(CompanySales['month_number'], CompanySales['bathingsoap'], marker = "o")
plt.plot(CompanySales['month_number'], CompanySales['shampoo'], marker = "o")
plt.plot(CompanySales['month_number'], CompanySales['moisturizer'],marker = "o")
plt.xlabel('Month of the Year')
plt.ylabel('Sales units in numbers')
plt.title('Sales data per products')
plt.xticks(ticks = range(1,13))
plt.yticks(ticks = range(1000,11000,1000))
plt.legend(labels = labels, fontsize = 'large')
plt.show()

# %%
plt.figure(figsize = (10,8))
plt.scatter(CompanySales['month_number'],
           CompanySales['toothpaste'])
plt.xlabel('Month of the Year')
plt.ylabel('Number of Units Sold')
plt.title('Toothpaste Sales per Month')
plt.xticks(ticks = range(1,13))
plt.yticks(ticks = range(4500,9000,500))
plt.grid(True, linestyle = '--')
plt.show()

# %%
plt.figure(figsize = (10,8))
x = np.arange(1, 13)
plt.bar(CompanySales['month_number'] , CompanySales['facecream'], 0.4,  label = 'facecream')
plt.bar(CompanySales['month_number'] + 0.4, CompanySales['facewash'], 0.4, label = 'facewash')
plt.xlabel('Month of the Year')
plt.ylabel('Sales units in numbers')
plt.title('Facewash and Facecream Sales data')
plt.xticks(ticks = range(1,13))
plt.yticks(ticks = range(0,4000,500))
plt.legend(loc = 2, labels = labels, fontsize = 'large')
plt.grid(True, linestyle = '--')
plt.show()

# %%
plt.figure(figsize =(10,8))
n = []
for i in CompanySales.columns: n.append(CompanySales.loc[:,i].sum())
Products = ['FaceCream', 'FaceWash', 'Toothpaste', 'BathingSoap', 'Shampoo', 'Moisturizer' ]
plt.pie(n[1:7], labels = Products, autopct = '%.1f%%')
plt.title("Sales Data")
plt.legend()
plt.show()
